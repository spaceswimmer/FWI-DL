# %%
import os
import sys

# Add the parent directory to the system path
sys.path.append("../")
sys.path.append("../synthoseis")

# %%
import synthoseis.main as mn 
import numpy as np
import json
import pprint as pp
import h5py as hdf
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import synthoseis.main as mn
#       2 import numpy as np
#       3 import json
#
# File ~/Documents/FWI-DL/src/../synthoseis/main.py:9
#       6 import numpy as np
#       7 import matplotlib.pyplot as plt
# ----> 9 from datagenerator.Closures import Closures
#      10 from datagenerator.Faults import Faults
#      11 from datagenerator.Geomodels import Geomodel
#
# ModuleNotFoundError: No module named 'datagenerator'

# %%
rock_model = json.load(open('../config/test-1.json', 'r'))
pp.pprint(rock_model)

# %%
mn.build_model(user_json='../config/example.json', run_id=1,test_mode=50)

# %%
seismic = np.load('../../data/synthetic_data/test1_test_mode_/seismic__2025.87592257_1/seismicCubes_RFC_fullstack_2025.87592257.npy')
geology = np.load('../../data/synthetic_data/test1_test_mode_/seismic__2025.87592257_1/trap_label_2025.87592257.npy')
print(geology.shape)

# %%
fig, axs = plt.subplots(1,2, figsize=(6,3))
iline = 10


fig.suptitle(f'Iline: {iline}')
axs[0].imshow(seismic[iline,:,:].T, cmap=plt.cm.seismic, aspect='auto')
axs[1].imshow(geology[iline,...].T, cmap=plt.cm.seismic, aspect='auto')
plt.show()
